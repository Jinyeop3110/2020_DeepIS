# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob

dirs = sorted(os.listdir("outs"))
list(enumerate(dirs))
# Out:
# [(0, '.ipynb_checkpoints'), (1, '__init__.py'), (2, 'test')]

# %%
target_dir = dirs[2]
print(target_dir)

from collections import OrderedDict
from Logger import Logger
target_dir = os.getcwd() + "/outs/" + target_dir
logger = Logger(target_dir)
# Out:
# test

# %%
# Train Plot
logger.log_plot("train", title="Train Log Graph")

# %%
# Valid plot
logger.log_plot("valid", title="Valid Acc Graph")
